# %%
#This is magic, don't touch it
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from html import unescape
import pandas as pd

# %%
with open('../corpus/registroactocom.csv', 'r') as file:
    unescaped_text = unescape(file.read())
    with open('../corpus/unescaped_text.csv', 'w') as unescaped_file:
        unescaped_file.write(unescaped_text)
    with open('../corpus/clean_text.csv', 'w') as clean_file:    
        clean_file.write(unescaped_text.replace('<p>', '')\
                         .replace('</p>', '')\
                         .replace('\r','')\
                         .replace('\xa0', ' '))

# %%
raw_dataset = pd.read_csv('../corpus/clean_text.csv', header=0)

# %%
raw_dataset.head()
# Out:
#    segmento_id  acto_id             titulo     palabrasclave  \
# 0            1        1       Presentación               NaN
# 1            2        2                NaN               NaN
# 2            3        5  Oficio de familia  Historia de vida
# 3            4        4       Presentación               NaN
# 4          499       22     Nuevo Amanecer               NaN
#
#                                        transcripcion   latitudp   longitudp
# 0  DEMETRIA: Nada más que yo orita ando previnien...  19.449715 -101.731987
# 1  MANUEL BAUTISTA: nosotros analizamos co, cómo,...  19.670720 -101.554051
# 2  00:00\nBERENICE: ¿Nos puede decir su nombre, s...  19.450582 -101.733160
# 3  VIDAL: […] Y, este… este año fue que , que hiz...  19.696462 -101.198387
# 4  SANTIAGO: Y tampoco queremos este obligarlos a...   0.000000    0.000000

# %%
new_dataset = raw_dataset.copy()

# %%
new_dataset.drop(columns=['titulo','palabrasclave','acto_id','latitudp','longitudp'])
# Out:
#      segmento_id                                      transcripcion
# 0              1  DEMETRIA: Nada más que yo orita ando previnien...
# 1              2  MANUEL BAUTISTA: nosotros analizamos co, cómo,...
# 2              3  00:00\nBERENICE: ¿Nos puede decir su nombre, s...
# 3              4  VIDAL: […] Y, este… este año fue que , que hiz...
# 4            499  SANTIAGO: Y tampoco queremos este obligarlos a...
# ..           ...                                                ...
# 404          659  GEORGINA: ¿Y sí encontraron ellos el dinero?\n...
# 405          660  GEORGINA: ¿O sea no a cualquiera les toca, pue...
# 406          661  GEORGINA: ¿Su papá entonces tampoco agarro din...
# 407          662  GEORGINA: ¿Cómo hace cuanto dejo de escuchar q...
# 408          663  GEORGINA: ¡Pues muchas gracias! ¿Algo más que ...
#
# [409 rows x 2 columns]

# %%
new_dataset.transcripcion[0]
# Out:
# 'DEMETRIA: Nada más que yo orita ando previniendo para bañiar, [ah] eso es que lo andaba haciendo ya, sí.\nBERENICE: A ver, no nos, no nos tardamos mucho.\nDEMETRIA: Ajá, sí. \nBERENICE: ¿Quién va a preguntar?\nGEORGINA: Pues, si quiere empezamos con su nombre [mjm] ¿Cómo se llama usted?\nDEMETRIA: Yo me llamo Demetria.\nGEORGINA: Demetria.\nBERENICE: ¿Y cómo se apellida? ¿Demetria qué?\nDEMETRIA: Antonio Guzmán [mjm]. \nBERENICE: ¿Y cuántos?\nGEORGINA: ¿Y cuántos años tiene? \nDEMETRIA: No, pos ya tengo setenta, setenta y dos.\nITZI: ¿Y nació aquí en la Pacanda? \nDEMETRIA: Sí, aquí, somos de aquí pues, nativos, sí.\nGEORGINA: ¿Su esposo también?\nDEMETRIA: Sí, también él, también sí, también ya está grande pues también él. Él lleva más, ganó, este, 4 años, me gana a mí. [Oh] Sí, sí. \n '

# %%
new_dataset.to_csv('../corpus/new_dataset.csv')

# %%
corpus = new_dataset.transcripcion.astype('str')

# %%
tfidf_vectorizer = TfidfVectorizer()

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(corpus)

# %%
print(tfidf_matrix)
# Out:
#   (0, 5838)	0.07683599486416617
#   (0, 5568)	0.05220013136239172
#   (0, 3920)	0.11614661436913616
#   (0, 3591)	0.02315241145816585
#   (0, 3930)	0.1034142766775673
#   (0, 4975)	0.07128343366745336
#   (0, 4003)	0.04793245304619705
#   (0, 3632)	0.029971805987293394
#   (0, 9042)	0.10978767418658493
#   (0, 7971)	0.1365476510726575
#   (0, 3547)	0.07295448338532443
#   (0, 5622)	0.1086986742730498
#   (0, 2553)	0.01947688746191057
#   (0, 7794)	0.06580045164653484
#   (0, 5970)	0.05220013136239172
#   (0, 4756)	0.01966823169675617
#   (0, 3182)	0.020911526188785598
#   (0, 824)	0.06980711898696919
#   (0, 5591)	0.08851839648539458
#   (0, 4583)	0.08658304176948912
#   (0, 2992)	0.04156082214837933
#   (0, 7651)	0.17316608353897825
#   (0, 8095)	0.051643456020621106
#   (0, 6560)	0.04727242226451916
#   (0, 8157)	0.03891111832905225
#   :	:
#   (407, 2065)	0.02210042811574396
#   (407, 7668)	0.09008843263389638
#   (407, 6800)	0.09871952665804555
#   (407, 3957)	0.0511863522069947
#   (407, 5500)	0.08737620120411807
#   (407, 5683)	0.12472172363560793
#   (407, 8985)	0.15176687281997142
#   (407, 5022)	0.0721203331277714
#   (407, 3414)	0.016988170963758563
#   (407, 3491)	0.018165684536634415
#   (407, 8996)	0.0413725727293686
#   (407, 6859)	0.12141616842725804
#   (407, 5595)	0.05430971915572405
#   (408, 7147)	0.28656726850407116
#   (408, 2174)	0.30727803768734646
#   (408, 3994)	0.46851584974764393
#   (408, 5499)	0.39021281808538777
#   (408, 6910)	0.26793761955321094
#   (408, 527)	0.18119766529032236
#   (408, 6800)	0.16930959000775966
#   (408, 3957)	0.526724991470738
#   (408, 5718)	0.12740854031393845
#   (408, 5683)	0.0802143124896339
#   (408, 6859)	0.07808835695674696
#   (408, 5558)	0.11042229830050387

# %%
#for i, feature in enumerate(tfidf_vectorizer.get_feature_names()):
 #   print(i, feature)
tfidf_vectorizer.get_feature_names()
# Out:
# ['00',
#  '000',
#  '000000',
#  '0001pt',
#  '000a',
#  '007b62b209a7',
#  '01',
#  '03',
#  '05',
#  '06',
#  '07',
#  '08c0590b088e',
#  '0be5',
#  '0cm',
#  '0pt',
#  '10',
#  '1050',
#  '107',
#  '11',
#  '115',
#  '1177',
#  '11pt',
#  '12',
#  '1250',
#  '12a6',
#  '12pt',
#  '13',
#  '14',
#  '1440',
#  '1450',
#  '149',
#  '1495',
#  '15',
#  '150',
#  '16',
#  '163',
#  '168',
#  '16px',
#  '18',
#  '1850',
#  '19',
#  '1927',
#  '1936',
#  '1945',
#  '1953',
#  '1960',
#  '1965',
#  '1972',
#  '1977',
#  '1ca510489c08',
#  '20',
#  '200',
#  '2000',
#  '2004',
#  '2005',
#  '2007',
#  '2008',
#  '2017',
#  '21',
#  '22',
#  '23',
#  '25',
#  '25pt',
#  '26',
#  '28',
#  '29',
#  '29f5',
#  '30',
#  '31',
#  '32',
#  '33',
#  '34',
#  '35',
#  '350',
#  '36',
#  '36bb',
#  '36pt',
#  '37',
#  '375',
#  '39',
#  '39af',
#  '3ad5',
#  '3d',
#  '3d1c74ed',
#  '3da8752c',
#  '40',
#  '400',
#  '41',
#  '42',
#  '43',
#  '44',
#  '45',
#  '450',
#  '45b65e14669a',
#  '46',
#  '4664ce00',
#  '47',
#  '48',
#  '49',
#  '4d80bbf58351',
#  '4d979725',
#  '4pt',
#  '50',
#  '51',
#  '52',
#  '53',
#  '55',
#  '56',
#  '57',
#  '5720662472ea',
#  '59eee6453c87',
#  '5ad67ddae1aa',
#  '5f5b',
#  '5pt',
#  '60',
#  '600',
#  '61',
#  '62',
#  '62fb',
#  '63',
#  '64',
#  '65',
#  '66',
#  '67',
#  '68',
#  '683b',
#  '69',
#  '6pt',
#  '70',
#  '71',
#  '72',
#  '73',
#  '75',
#  '7999999999999998',
#  '7f74',
#  '7fa3',
#  '7fde',
#  '7fff',
#  '7pt',
#  '80',
#  '8058bad9',
#  '81',
#  '85',
#  '86',
#  '87',
#  '88',
#  '895ae6e2cec1',
#  '91ce',
#  '92',
#  '9696',
#  '96c55f1b',
#  '9730',
#  '99',
#  '9b9b680b',
#  '9fc1',
#  '9pt',
#  'a317db4d',
#  'aa',
#  'aaah',
#  'aaahh',
#  'aah',
#  'abad',
#  'abae4658d944',
#  'abajeños',
#  'abajito',
#  'abajo',
#  'abandona',
#  'abarca',
#  'abastecer',
#  'abasto',
#  'abeja',
#  'abierta',
#  'abierto',
#  'abordaron',
#  'abrace',
#  'abraham',
#  'abrazado',
#  'abrazar',
#  'abrazo',
#  'abrazó',
#  'abriendo',
#  'abrieron',
#  'abril',
#  'abrir',
#  'abrió',
#  'abrázame',
#  'abría',
#  'abrían',
#  'absolutamente',
#  'abuelas',
#  'abuelita',
#  'abuelitas',
#  'abuelito',
#  'abuelitos',
#  'abuelo',
#  'abuelos',
#  'abuelto',
#  'abueluchani',
#  'abunda',
#  'abundaba',
#  'abundaban',
#  'abundad',
#  'abundantemente',
#  'abundaron',
#  'abusados',
#  'abusé',
#  'abá',
#  'acaba',
#  'acababa',
#  'acabado',
#  'acabamos',
#  'acaban',
#  'acabando',
#  'acabar',
#  'acabara',
#  'acabaron',
#  'acabe',
#  'acabo',
#  'acabé',
#  'acabó',
#  'acalorizada',
#  'acampábamos',
#  'acaparon',
#  'acarreaban',
#  'acarrear',
#  'acarrearlo',
#  'acarrearse',
#  'acarreo',
#  'acarreábamos',
#  'accent',
#  'accidentalmente',
#  'accidente',
#  'acción',
#  'aceite',
#  'acepta',
#  'aceptamos',
#  'aceptan',
#  'aceptar',
#  'aceptarle',
#  'aceptó',
#  'acerca',
#  'acercaban',
#  'acercado',
#  'acercando',
#  'acercar',
#  'acercaran',
#  'acerco',
#  'acerqué',
#  'achoque',
#  'aclamaba',
#  'aclarando',
#  'aclarar',
#  'acomedían',
#  'acomodado',
#  'acomodamos',
#  'acomodaron',
#  'acomodé',
#  'acomodó',
#  'acompaña',
#  'acompañaba',
#  'acompañada',
#  'acompañado',
#  'acompañan',
#  'acompañando',
#  'acompañantes',
#  'acompañar',
#  'acompañara',
#  'acompañarlos',
#  'acompañarme',
#  'acompañe',
#  'acompañen',
#  'acompañes',
#  'acompaño',
#  'acompañó',
#  'acompáñame',
#  'acondicionadas',
#  'acondicionar',
#  'acordaba',
#  'acordaban',
#  'acordabas',
#  'acordado',
#  'acordamos',
#  'acordando',
#  'acordar',
#  'acordara',
#  'acordarse',
#  'acordé',
#  'acordó',
#  'acorralado',
#  'acostada',
#  'acostado',
#  'acostumbra',
#  'acostumbraba',
#  'acostumbrada',
#  'acostumbrado',
#  'acostumbrados',
#  'acostumbramos',
#  'acostumbrando',
#  'acostumbraron',
#  'acostumbrábamos',
#  'acosté',
#  'acrodó',
#  'acronym',
#  'actividades',
#  'acto',
#  'actual',
#  'actualidad',
#  'actualizado',
#  'actualmente',
#  'acudieran',
#  'acudir',
#  'acudían',
#  'acuerda',
#  'acuerdan',
#  'acuerdas',
#  'acuerde',
#  'acuerdes',
#  'acuerdo',
#  'acuesta',
#  'acuestas',
#  'acumara',
#  'acumaras',
#  'acumulación',
#  'acumuladores',
#  'acumulando',
#  'acumura',
#  'acumuras',
#  'acusar',
#  'acuéstate',
#  'acá',
#  'acércate',
#  'acúmara',
#  'acúmaras',
#  'adando',
#  'adaptada',
#  'add',
#  'address',
#  'ade',
#  'adecuado',
#  'adela',
#  'adelantaron',
#  'adelante',
#  'además',
#  'adentro',
#  'adivinanzas',
#  'administraba',
#  'administrador',
#  'adobe',
#  'adolescentes',
#  'adorar',
#  'adornada',
#  'adornado',
#  'adornan',
#  'adornar',
#  'adornarlo',
#  'adornitos',
#  'adorno',
#  'adornos',
#  'adquirido',
#  'adquiriendo',
#  'adquirir',
#  'adueñó',
#  'adulta',
#  'adultos',
#  'aeso',
#  'afecta',
#  'afectando',
#  'afectaran',
#  'afectó',
#  'afligido',
#  'afortunadamente',
#  'afortunado',
#  'afortunados',
#  'afuera',
#  'afuerita',
#  'agachado',
#  'agalleras',
#  'agarra',
#  'agarraba',
#  'agarraban',
#  'agarrabas',
#  'agarrado',
#  'agarramos',
#  'agarran',
#  'agarrancan',
#  'agarrando',
#  'agarrar',
#  'agarrara',
#  'agarrarla',
#  'agarrarlo',
#  'agarraron',
#  'agarrarían',
#  'agarras',
#  'agarre',
#  'agarren',
#  'agarres',
#  'agarro',
#  'agarrábamos',
#  'agarrámos',
#  'agarré',
#  'agarró',
#  'agonía',
#  'agosto',
#  'agrada',
#  'agradable',
#  'agrade',
#  'agradecernos',
#  'agradecimiento',
#  'agradézcame',
#  'agre',
#  'agredir',
#  'agregando',
#  'agregar',
#  'agregaron',
#  'agronazos',
#  'agu',
#  'agua',
#  'aguacate',
#  'aguacateros',
#  'aguacates',
#  'aguacera',
#  'aguacero',
#  'aguanta',
#  'aguantan',
#  'aguantar',
#  'aguantaron',
#  'aguante',
#  'aguanto',
#  'aguanté',
#  'aguantó',
#  'aguas',
#  'aguascalientes',
#  'agudo',
#  'aguelita',
#  'aguelito',
#  'agujeran',
#  'agujerito',
#  'agustina',
#  'agusto',
#  'agárralo',
#  'agárrame',
#  'agüelita',
#  'agüelito',
#  'agüelitos',
#  'agüelo',
#  'agüeluri',
#  'agüita',
#  'ah',
#  'ahi',
#  'ahm',
#  'ahogaba',
#  'ahogaban',
#  'ahogado',
#  'ahogados',
#  'ahogamos',
#  'ahogan',
#  'ahogando',
#  'ahogao',
#  'ahogar',
#  'ahogara',
#  'ahogaran',
#  'ahogaron',
#  'ahogue',
#  'ahogó',
#  'ahora',
#  'ahorita',
#  'ahorrando',
#  'ahorrar',
#  'ahumadito',
#  'ahí',
#  'aiaku',
#  'aiankosani',
#  'aiankuni',
#  'aigre',
#  'air',
#  'aire',
#  'airecito',
#  'airesón',
#  'aja',
#  'ajaja',
#  'ajajá',
#  'ajolote',
#  'ajolotes',
#  'ajuera',
#  'ajuste',
#  'ajà',
#  'ajá',
#  'aján',
#  'akumara',
#  'akumaras',
#  'akúmara',
#  'akúmaras',
#  'al',
#  'alabanzas',
#  'aladino',
#  'alambre',
#  'alambrito',
#  'alaska',
#  'albañil',
#  'albañilería',
#  'alberto',
#  'alcacez',
#  'alcance',
#  'alcancé',
#  'alcanza',
#  'alcanzaba',
#  'alcanzaban',
#  'alcanzamos',
#  'alcanzan',
#  'alcanzar',
#  'alcanzarla',
#  'alcanzaron',
#  'alcanzo',
#  'alcanzó',
#  'alcen',
#  'alcohol',
#  'alegre',
#  'alegres',
#  'alejados',
#  'alejando',
#  'alejandra',
#  'alejandro',
#  'alejarse',
#  'alejo',
#  'alemania',
#  'alertó',
#  'alfabetización',
#  'algo',
#  'algodón',
#  'algu',
#  'alguien',
#  'alguna',
#  'algunas',
#  'alguno',
#  'algunos',
#  'algún',
#  'alicia',
#  'align',
#  'alimentan',
#  'alimento',
#  'alimentos',
#  'aliviar',
#  'alivien',
#  'aljibe',
#  'aljibes',
#  'allowpng',
#  'allá',
#  'allí',
#  'alló',
#  'alma',
#  'almanza',
#  'almas',
#  'almorzar',
#  'almuerzo',
#  'alo',
#  'alomejor',
#  'alrededor',
#  'alt',
#  'altar',
#  'altares',
#  'altas',
#  'altecido',
#  'alternativa',
#  'altita',
#  'altito',
#  'alto',
#  'altura',
#  'alucina',
#  'alumbraba',
#  'alumbraban',
#  'alumbrado',
#  'alumbran',
#  'alumbrando',
#  'alumbrar',
#  'alumbrarse',
#  'alumbre',
#  'alumbró',
#  'alumno',
#  'alumnos',
#  'alwaysshowplaceholdertext',
#  'alzarlo',
#  'alzaron',
#  'am',
#  'ama',
#  'amador',
#  'amanece',
#  'amanecer',
#  'amanecido',
#  'amaneciendo',
#  'amaneció',
#  'amanecíamos',
#  'amanecían',
#  'amanezca',
#  'amansar',
#  'amansarlo',
#  'amarilla',
#  'amarillista',
#  'amarillo',
#  'amarradas',
#  'amarrado',
#  'amarrados',
#  'amarran',
#  'amarrar',
#  'amarrarlo',
#  'amarrábamos',
#  'amasiato',
#  'ambas',
#  'ambicionar',
#  'ambición',
#  'ambiente',
#  'ambos',
#  'ambulancia',
#  'ameno',
#  'amigo',
#  'amigos',
#  'aminorando',
#  'amistad',
#  'amistades',
#  'amontonaban',
#  'amor',
#  'amos',
#  'ampe',
#  'ampechani',
#  'ampenkani',
#  'ampeskia',
#  'amplia',
#  'ampliando',
#  'amplias',
#  'amplio',
#  'américa',
#  'an',
#  'ana',
#  'anagua',
#  'analizabas',
#  'analizamos',
#  'analizar',
#  'anapizaro',
#  'anapuepka',
#  'anapueska',
#  'ancho',
#  'anda',
#  'andaba',
#  'andabamos',
#  'andaban',
#  'andabas',
#  'andado',
#  'andador',
#  'andale',
#  'andamos',
#  'andan',
#  'andando',
#  'andar',
#  'andas',
#  'ande',
#  'anden',
#  'andes',
#  'ando',
#  'andrade',
#  'andrés',
#  'andu',
#  'anduve',
#  'anduviera',
#  'anduvieron',
#  'anduvimos',
#  'anduviéramos',
#  'anduvo',
#  'anduví',
#  'andábamos',
#  'angelito',
#  'angelitos',
#  'anhapueskits',
#  'anim',
#  'anima',
#  'animaba',
#  'animal',
#  'animales',
#  'animalito',
#  'animalitos',
#  'animan',
#  'animaron',
#  'animó',
#  'annotation',
#  'anoche',
#  'anomalía',
#  'anotar',
#  'ansi',
#  'ansina',
#  'ansí',
#  'ante',
#  'antecesores',
#  'antepasados',
#  'anteriormente',
#  'antes',
#  'antigua',
#  'antiguas',
#  'antiguo',
#  'antiguos',
#  'antigüitas',
#  'antojaban',
#  'antonces',
#  'antonio',
#  'anuncian',
#  'anunciando',
#  'anunciar',
#  'anuncio',
#  'anzuelo',
#  'anécdota',
#  'ap',
#  'apache',
#  'apacito',
#  'apaga',
#  'apagaba',
#  'apagaban',
#  'apagadas',
#  'apagar',
#  'apago',
#  'apapacho',
#  'apapachándose',
#  'aparador',
#  'aparatito',
#  'aparatitos',
#  'aparato',
#  'aparatos',
#  'aparece',
#  'aparecen',
#  'aparecer',
#  'aparecerse',
#  'aparecerá',
#  'aparecido',
#  'aparecidos',
#  'apareciendo',
#  'apareciera',
#  'aparecieron',
#  'apareció',
#  'aparecía',
#  'aparecían',
#  'aparecío',
#  'aparente',
#  'aparezca',
#  'aparezcan',
#  'aparezco',
#  'aparicio',
#  'apariciones',
#  'apartaba',
#  'aparte',
#  'apatzingán',
#  'apeidos',
#  'apellida',
#  'apellido',
#  'apellidos',
#  'apenas',
#  'aplanados',
#  'aplasté',
#  'aplastó',
#  'aplicaba',
#  'aplicarse',
#  'apoco',
#  'apongio',
#  'aponguio',
#  'aportaciones',
#  'apostol',
#  'apostólica',
#  'apoya',
#  'apoyada',
#  'apoyado',
#  'apoyando',
#  'apoyar',
#  'apoyara',
#  'apoyarle',
#  'apoyarlo',
#  'apoyarlos',
#  'apoyarnos',
#  'apoyes',
#  'apoyo',
#  'apoyándome',
#  'apoyándonos',
#  'apoyó',
#  'apre',
#  'apreciaban',
#  'apreciar',
#  'aprecio',
#  'aprehensión',
#  'aprendan',
#  'aprende',
#  'aprendemos',
#  'aprenden',
#  'aprender',
#  'aprendido',
#  'aprendiendo',
#  'aprendieron',
#  'aprendiste',
#  'aprendizaje',
#  'aprendió',
#  'aprendérmelos',
#  'aprendí',
#  'aprieto',
#  'aprobado',
#  'apropió',
#  'aprovecha',
#  'aprovechamos',
#  'aprovechan',
#  'aprovechando',
#  'aprovechar',
#  'aprovecharlo',
#  'aprovecharon',
#  'aprovechas',
#  'aproveche',
#  'aproximadamente',
#  'aproximando',
#  'apuntar',
#  'apuraba',
#  'apures',
#  'apá',
#  'apártate',
#  'apóstol',
#  'apóyenlos',
#  'aqueja',
#  'aquel',
#  'aquella',
#  'aquellas',
#  'aquello',
#  'aquellos',
#  'aqui',
#  'aquél',
#  'aquí',
#  'ar',
#  'arado',
#  'araró',
#  'ararón',
#  'arboles',
#  'arbolito',
#  'arbolitos',
#  'arbustos',
#  'archivo',
#  'arco',
#  'arcos',
#  'arena',
#  'aretes',
#  'argentina',
#  'arhijki',
#  'arhikuarheska',
#  'arhikuarhixaki',
#  'arhinhasini',
#  'arhisi',
#  'arial',
#  'aricutín',
#  'arma',
#  'armando',
#  'armar',
#  'armarlo',
#  'armas',
#  'armábamos',
#  'armó',
#  'arnulfo',
#  'arocutín',
#  'aroma',
#  'arquitecto',
#  'arranca',
#  'arrastra',
#  'arrastramos',
#  'arrastran',
#  'arrastrar',
#  'arrastrarse',
#  'arrastre',
#  'arrastres',
#  'arrebata',
#  'arrebató',
#  'arreglaba',
#  'arreglaban',
#  'arreglado',
#  'arreglados',
#  'arreglar',
#  'arreglara',
#  'arreglarlo',
#  'arreglaron',
#  'arregles',
#  'arreglo',
#  'arreglos',
#  'arregló',
#  'arremangó',
#  'arreola',
#  'arrepiente',
#  'arriaban',
#  'arriar',
#  'arriba',
#  'arribita',
#  'arrieros',
#  'arriesgamos',
#  'arriesgando',
#  'arriesgaron',
#  'arriesgáramos',
#  'arrima',
#  'arrimaba',
#  'arrimada',
#  'arrimando',
#  'arrimarse',
#  'arrime',
#  'arrimo',
#  'arrimándose',
#  'arrimármelos',
#  'arrimó',
#  'arrobalo',
#  'arrojaba',
#  'arroyo',
#  'arroz',
#  'arréglense',
#  'arte',
#  'artes',
#  'artesanía',
#  'arto',
#  'artos',
#  'arócutin',
#  'asa',
#  'asadas',
#  'asaditas',
#  'asadito',
#  'asaditos',
#  'asado',
#  'asajo',
#  'asaltan',
#  'asaltar',
#  'asalté',
#  'asamblea',
#  'asan',
#  'asando',
#  'asar',
#  'asarlo',
#  'asarlos',
#  'ascii',
#  'asegurado',
#  'asegurar',
#  'aseguren',
#  'aseguro',
#  'asentamiento',
#  'asentaron',
#  'asi',
#  'asian',
#  'asiente',
#  'asignan',
#  'asina',
#  'asinita',
#  'asistencia',
#  'asistente',
#  'asistía',
#  'asistían',
#  'asoman',
#  'asomó',
#  'aspecto',
#  'asquerosa',
#  'ass',
#  'asunto',
#  'asust',
#  'asusta',
#  'asustaba',
#  'asustadas',
#  'asustado',
#  'asustan',
#  'asustar',
#  'asustarlo',
#  'asusté',
#  'asustó',
#  'asá',
#  'asì',
#  'así',
#  'ata',
#  'ataca',
#  'atacar',
#  'ataque',
#  'ate',
#  'atecua',
#  'atekua',
#  'atención',
#  'atender',
#  'atendiera',
#  'atendió',
#  'atendían',
#  'atenta',
#  'aterrizamos',
#  'ates',
#  'atestigar',
#  'atestiguamos',
#  'atestiguar',
#  'atienden',
#  'atole',
#  'atolito',
#  'atorar',
#  'atracción',
#  'atraer',
#  'atrapado',
#  'atrapen',
#  'atravesaba',
#  'atravesaban',
#  'atravesar',
#  'atravesó',
#  'atraviesa',
#  'atraviese',
#  'atraía',
#  'atrevió',
#  'atrio',
#  'atropellan',
#  ...]

# %%
tf_vectorizer = CountVectorizer()

# %%
tf_matrix = tf_vectorizer.fit_transform(corpus)

# %%
#for i, feature in enumerate(tf_vectorizer.get_feature_names()):
 #   print(i, feature)
tf_vectorizer.get_feature_names()
# Out:
# ['00',
#  '000',
#  '000000',
#  '0001pt',
#  '000a',
#  '007b62b209a7',
#  '01',
#  '03',
#  '05',
#  '06',
#  '07',
#  '08c0590b088e',
#  '0be5',
#  '0cm',
#  '0pt',
#  '10',
#  '1050',
#  '107',
#  '11',
#  '115',
#  '1177',
#  '11pt',
#  '12',
#  '1250',
#  '12a6',
#  '12pt',
#  '13',
#  '14',
#  '1440',
#  '1450',
#  '149',
#  '1495',
#  '15',
#  '150',
#  '16',
#  '163',
#  '168',
#  '16px',
#  '18',
#  '1850',
#  '19',
#  '1927',
#  '1936',
#  '1945',
#  '1953',
#  '1960',
#  '1965',
#  '1972',
#  '1977',
#  '1ca510489c08',
#  '20',
#  '200',
#  '2000',
#  '2004',
#  '2005',
#  '2007',
#  '2008',
#  '2017',
#  '21',
#  '22',
#  '23',
#  '25',
#  '25pt',
#  '26',
#  '28',
#  '29',
#  '29f5',
#  '30',
#  '31',
#  '32',
#  '33',
#  '34',
#  '35',
#  '350',
#  '36',
#  '36bb',
#  '36pt',
#  '37',
#  '375',
#  '39',
#  '39af',
#  '3ad5',
#  '3d',
#  '3d1c74ed',
#  '3da8752c',
#  '40',
#  '400',
#  '41',
#  '42',
#  '43',
#  '44',
#  '45',
#  '450',
#  '45b65e14669a',
#  '46',
#  '4664ce00',
#  '47',
#  '48',
#  '49',
#  '4d80bbf58351',
#  '4d979725',
#  '4pt',
#  '50',
#  '51',
#  '52',
#  '53',
#  '55',
#  '56',
#  '57',
#  '5720662472ea',
#  '59eee6453c87',
#  '5ad67ddae1aa',
#  '5f5b',
#  '5pt',
#  '60',
#  '600',
#  '61',
#  '62',
#  '62fb',
#  '63',
#  '64',
#  '65',
#  '66',
#  '67',
#  '68',
#  '683b',
#  '69',
#  '6pt',
#  '70',
#  '71',
#  '72',
#  '73',
#  '75',
#  '7999999999999998',
#  '7f74',
#  '7fa3',
#  '7fde',
#  '7fff',
#  '7pt',
#  '80',
#  '8058bad9',
#  '81',
#  '85',
#  '86',
#  '87',
#  '88',
#  '895ae6e2cec1',
#  '91ce',
#  '92',
#  '9696',
#  '96c55f1b',
#  '9730',
#  '99',
#  '9b9b680b',
#  '9fc1',
#  '9pt',
#  'a317db4d',
#  'aa',
#  'aaah',
#  'aaahh',
#  'aah',
#  'abad',
#  'abae4658d944',
#  'abajeños',
#  'abajito',
#  'abajo',
#  'abandona',
#  'abarca',
#  'abastecer',
#  'abasto',
#  'abeja',
#  'abierta',
#  'abierto',
#  'abordaron',
#  'abrace',
#  'abraham',
#  'abrazado',
#  'abrazar',
#  'abrazo',
#  'abrazó',
#  'abriendo',
#  'abrieron',
#  'abril',
#  'abrir',
#  'abrió',
#  'abrázame',
#  'abría',
#  'abrían',
#  'absolutamente',
#  'abuelas',
#  'abuelita',
#  'abuelitas',
#  'abuelito',
#  'abuelitos',
#  'abuelo',
#  'abuelos',
#  'abuelto',
#  'abueluchani',
#  'abunda',
#  'abundaba',
#  'abundaban',
#  'abundad',
#  'abundantemente',
#  'abundaron',
#  'abusados',
#  'abusé',
#  'abá',
#  'acaba',
#  'acababa',
#  'acabado',
#  'acabamos',
#  'acaban',
#  'acabando',
#  'acabar',
#  'acabara',
#  'acabaron',
#  'acabe',
#  'acabo',
#  'acabé',
#  'acabó',
#  'acalorizada',
#  'acampábamos',
#  'acaparon',
#  'acarreaban',
#  'acarrear',
#  'acarrearlo',
#  'acarrearse',
#  'acarreo',
#  'acarreábamos',
#  'accent',
#  'accidentalmente',
#  'accidente',
#  'acción',
#  'aceite',
#  'acepta',
#  'aceptamos',
#  'aceptan',
#  'aceptar',
#  'aceptarle',
#  'aceptó',
#  'acerca',
#  'acercaban',
#  'acercado',
#  'acercando',
#  'acercar',
#  'acercaran',
#  'acerco',
#  'acerqué',
#  'achoque',
#  'aclamaba',
#  'aclarando',
#  'aclarar',
#  'acomedían',
#  'acomodado',
#  'acomodamos',
#  'acomodaron',
#  'acomodé',
#  'acomodó',
#  'acompaña',
#  'acompañaba',
#  'acompañada',
#  'acompañado',
#  'acompañan',
#  'acompañando',
#  'acompañantes',
#  'acompañar',
#  'acompañara',
#  'acompañarlos',
#  'acompañarme',
#  'acompañe',
#  'acompañen',
#  'acompañes',
#  'acompaño',
#  'acompañó',
#  'acompáñame',
#  'acondicionadas',
#  'acondicionar',
#  'acordaba',
#  'acordaban',
#  'acordabas',
#  'acordado',
#  'acordamos',
#  'acordando',
#  'acordar',
#  'acordara',
#  'acordarse',
#  'acordé',
#  'acordó',
#  'acorralado',
#  'acostada',
#  'acostado',
#  'acostumbra',
#  'acostumbraba',
#  'acostumbrada',
#  'acostumbrado',
#  'acostumbrados',
#  'acostumbramos',
#  'acostumbrando',
#  'acostumbraron',
#  'acostumbrábamos',
#  'acosté',
#  'acrodó',
#  'acronym',
#  'actividades',
#  'acto',
#  'actual',
#  'actualidad',
#  'actualizado',
#  'actualmente',
#  'acudieran',
#  'acudir',
#  'acudían',
#  'acuerda',
#  'acuerdan',
#  'acuerdas',
#  'acuerde',
#  'acuerdes',
#  'acuerdo',
#  'acuesta',
#  'acuestas',
#  'acumara',
#  'acumaras',
#  'acumulación',
#  'acumuladores',
#  'acumulando',
#  'acumura',
#  'acumuras',
#  'acusar',
#  'acuéstate',
#  'acá',
#  'acércate',
#  'acúmara',
#  'acúmaras',
#  'adando',
#  'adaptada',
#  'add',
#  'address',
#  'ade',
#  'adecuado',
#  'adela',
#  'adelantaron',
#  'adelante',
#  'además',
#  'adentro',
#  'adivinanzas',
#  'administraba',
#  'administrador',
#  'adobe',
#  'adolescentes',
#  'adorar',
#  'adornada',
#  'adornado',
#  'adornan',
#  'adornar',
#  'adornarlo',
#  'adornitos',
#  'adorno',
#  'adornos',
#  'adquirido',
#  'adquiriendo',
#  'adquirir',
#  'adueñó',
#  'adulta',
#  'adultos',
#  'aeso',
#  'afecta',
#  'afectando',
#  'afectaran',
#  'afectó',
#  'afligido',
#  'afortunadamente',
#  'afortunado',
#  'afortunados',
#  'afuera',
#  'afuerita',
#  'agachado',
#  'agalleras',
#  'agarra',
#  'agarraba',
#  'agarraban',
#  'agarrabas',
#  'agarrado',
#  'agarramos',
#  'agarran',
#  'agarrancan',
#  'agarrando',
#  'agarrar',
#  'agarrara',
#  'agarrarla',
#  'agarrarlo',
#  'agarraron',
#  'agarrarían',
#  'agarras',
#  'agarre',
#  'agarren',
#  'agarres',
#  'agarro',
#  'agarrábamos',
#  'agarrámos',
#  'agarré',
#  'agarró',
#  'agonía',
#  'agosto',
#  'agrada',
#  'agradable',
#  'agrade',
#  'agradecernos',
#  'agradecimiento',
#  'agradézcame',
#  'agre',
#  'agredir',
#  'agregando',
#  'agregar',
#  'agregaron',
#  'agronazos',
#  'agu',
#  'agua',
#  'aguacate',
#  'aguacateros',
#  'aguacates',
#  'aguacera',
#  'aguacero',
#  'aguanta',
#  'aguantan',
#  'aguantar',
#  'aguantaron',
#  'aguante',
#  'aguanto',
#  'aguanté',
#  'aguantó',
#  'aguas',
#  'aguascalientes',
#  'agudo',
#  'aguelita',
#  'aguelito',
#  'agujeran',
#  'agujerito',
#  'agustina',
#  'agusto',
#  'agárralo',
#  'agárrame',
#  'agüelita',
#  'agüelito',
#  'agüelitos',
#  'agüelo',
#  'agüeluri',
#  'agüita',
#  'ah',
#  'ahi',
#  'ahm',
#  'ahogaba',
#  'ahogaban',
#  'ahogado',
#  'ahogados',
#  'ahogamos',
#  'ahogan',
#  'ahogando',
#  'ahogao',
#  'ahogar',
#  'ahogara',
#  'ahogaran',
#  'ahogaron',
#  'ahogue',
#  'ahogó',
#  'ahora',
#  'ahorita',
#  'ahorrando',
#  'ahorrar',
#  'ahumadito',
#  'ahí',
#  'aiaku',
#  'aiankosani',
#  'aiankuni',
#  'aigre',
#  'air',
#  'aire',
#  'airecito',
#  'airesón',
#  'aja',
#  'ajaja',
#  'ajajá',
#  'ajolote',
#  'ajolotes',
#  'ajuera',
#  'ajuste',
#  'ajà',
#  'ajá',
#  'aján',
#  'akumara',
#  'akumaras',
#  'akúmara',
#  'akúmaras',
#  'al',
#  'alabanzas',
#  'aladino',
#  'alambre',
#  'alambrito',
#  'alaska',
#  'albañil',
#  'albañilería',
#  'alberto',
#  'alcacez',
#  'alcance',
#  'alcancé',
#  'alcanza',
#  'alcanzaba',
#  'alcanzaban',
#  'alcanzamos',
#  'alcanzan',
#  'alcanzar',
#  'alcanzarla',
#  'alcanzaron',
#  'alcanzo',
#  'alcanzó',
#  'alcen',
#  'alcohol',
#  'alegre',
#  'alegres',
#  'alejados',
#  'alejando',
#  'alejandra',
#  'alejandro',
#  'alejarse',
#  'alejo',
#  'alemania',
#  'alertó',
#  'alfabetización',
#  'algo',
#  'algodón',
#  'algu',
#  'alguien',
#  'alguna',
#  'algunas',
#  'alguno',
#  'algunos',
#  'algún',
#  'alicia',
#  'align',
#  'alimentan',
#  'alimento',
#  'alimentos',
#  'aliviar',
#  'alivien',
#  'aljibe',
#  'aljibes',
#  'allowpng',
#  'allá',
#  'allí',
#  'alló',
#  'alma',
#  'almanza',
#  'almas',
#  'almorzar',
#  'almuerzo',
#  'alo',
#  'alomejor',
#  'alrededor',
#  'alt',
#  'altar',
#  'altares',
#  'altas',
#  'altecido',
#  'alternativa',
#  'altita',
#  'altito',
#  'alto',
#  'altura',
#  'alucina',
#  'alumbraba',
#  'alumbraban',
#  'alumbrado',
#  'alumbran',
#  'alumbrando',
#  'alumbrar',
#  'alumbrarse',
#  'alumbre',
#  'alumbró',
#  'alumno',
#  'alumnos',
#  'alwaysshowplaceholdertext',
#  'alzarlo',
#  'alzaron',
#  'am',
#  'ama',
#  'amador',
#  'amanece',
#  'amanecer',
#  'amanecido',
#  'amaneciendo',
#  'amaneció',
#  'amanecíamos',
#  'amanecían',
#  'amanezca',
#  'amansar',
#  'amansarlo',
#  'amarilla',
#  'amarillista',
#  'amarillo',
#  'amarradas',
#  'amarrado',
#  'amarrados',
#  'amarran',
#  'amarrar',
#  'amarrarlo',
#  'amarrábamos',
#  'amasiato',
#  'ambas',
#  'ambicionar',
#  'ambición',
#  'ambiente',
#  'ambos',
#  'ambulancia',
#  'ameno',
#  'amigo',
#  'amigos',
#  'aminorando',
#  'amistad',
#  'amistades',
#  'amontonaban',
#  'amor',
#  'amos',
#  'ampe',
#  'ampechani',
#  'ampenkani',
#  'ampeskia',
#  'amplia',
#  'ampliando',
#  'amplias',
#  'amplio',
#  'américa',
#  'an',
#  'ana',
#  'anagua',
#  'analizabas',
#  'analizamos',
#  'analizar',
#  'anapizaro',
#  'anapuepka',
#  'anapueska',
#  'ancho',
#  'anda',
#  'andaba',
#  'andabamos',
#  'andaban',
#  'andabas',
#  'andado',
#  'andador',
#  'andale',
#  'andamos',
#  'andan',
#  'andando',
#  'andar',
#  'andas',
#  'ande',
#  'anden',
#  'andes',
#  'ando',
#  'andrade',
#  'andrés',
#  'andu',
#  'anduve',
#  'anduviera',
#  'anduvieron',
#  'anduvimos',
#  'anduviéramos',
#  'anduvo',
#  'anduví',
#  'andábamos',
#  'angelito',
#  'angelitos',
#  'anhapueskits',
#  'anim',
#  'anima',
#  'animaba',
#  'animal',
#  'animales',
#  'animalito',
#  'animalitos',
#  'animan',
#  'animaron',
#  'animó',
#  'annotation',
#  'anoche',
#  'anomalía',
#  'anotar',
#  'ansi',
#  'ansina',
#  'ansí',
#  'ante',
#  'antecesores',
#  'antepasados',
#  'anteriormente',
#  'antes',
#  'antigua',
#  'antiguas',
#  'antiguo',
#  'antiguos',
#  'antigüitas',
#  'antojaban',
#  'antonces',
#  'antonio',
#  'anuncian',
#  'anunciando',
#  'anunciar',
#  'anuncio',
#  'anzuelo',
#  'anécdota',
#  'ap',
#  'apache',
#  'apacito',
#  'apaga',
#  'apagaba',
#  'apagaban',
#  'apagadas',
#  'apagar',
#  'apago',
#  'apapacho',
#  'apapachándose',
#  'aparador',
#  'aparatito',
#  'aparatitos',
#  'aparato',
#  'aparatos',
#  'aparece',
#  'aparecen',
#  'aparecer',
#  'aparecerse',
#  'aparecerá',
#  'aparecido',
#  'aparecidos',
#  'apareciendo',
#  'apareciera',
#  'aparecieron',
#  'apareció',
#  'aparecía',
#  'aparecían',
#  'aparecío',
#  'aparente',
#  'aparezca',
#  'aparezcan',
#  'aparezco',
#  'aparicio',
#  'apariciones',
#  'apartaba',
#  'aparte',
#  'apatzingán',
#  'apeidos',
#  'apellida',
#  'apellido',
#  'apellidos',
#  'apenas',
#  'aplanados',
#  'aplasté',
#  'aplastó',
#  'aplicaba',
#  'aplicarse',
#  'apoco',
#  'apongio',
#  'aponguio',
#  'aportaciones',
#  'apostol',
#  'apostólica',
#  'apoya',
#  'apoyada',
#  'apoyado',
#  'apoyando',
#  'apoyar',
#  'apoyara',
#  'apoyarle',
#  'apoyarlo',
#  'apoyarlos',
#  'apoyarnos',
#  'apoyes',
#  'apoyo',
#  'apoyándome',
#  'apoyándonos',
#  'apoyó',
#  'apre',
#  'apreciaban',
#  'apreciar',
#  'aprecio',
#  'aprehensión',
#  'aprendan',
#  'aprende',
#  'aprendemos',
#  'aprenden',
#  'aprender',
#  'aprendido',
#  'aprendiendo',
#  'aprendieron',
#  'aprendiste',
#  'aprendizaje',
#  'aprendió',
#  'aprendérmelos',
#  'aprendí',
#  'aprieto',
#  'aprobado',
#  'apropió',
#  'aprovecha',
#  'aprovechamos',
#  'aprovechan',
#  'aprovechando',
#  'aprovechar',
#  'aprovecharlo',
#  'aprovecharon',
#  'aprovechas',
#  'aproveche',
#  'aproximadamente',
#  'aproximando',
#  'apuntar',
#  'apuraba',
#  'apures',
#  'apá',
#  'apártate',
#  'apóstol',
#  'apóyenlos',
#  'aqueja',
#  'aquel',
#  'aquella',
#  'aquellas',
#  'aquello',
#  'aquellos',
#  'aqui',
#  'aquél',
#  'aquí',
#  'ar',
#  'arado',
#  'araró',
#  'ararón',
#  'arboles',
#  'arbolito',
#  'arbolitos',
#  'arbustos',
#  'archivo',
#  'arco',
#  'arcos',
#  'arena',
#  'aretes',
#  'argentina',
#  'arhijki',
#  'arhikuarheska',
#  'arhikuarhixaki',
#  'arhinhasini',
#  'arhisi',
#  'arial',
#  'aricutín',
#  'arma',
#  'armando',
#  'armar',
#  'armarlo',
#  'armas',
#  'armábamos',
#  'armó',
#  'arnulfo',
#  'arocutín',
#  'aroma',
#  'arquitecto',
#  'arranca',
#  'arrastra',
#  'arrastramos',
#  'arrastran',
#  'arrastrar',
#  'arrastrarse',
#  'arrastre',
#  'arrastres',
#  'arrebata',
#  'arrebató',
#  'arreglaba',
#  'arreglaban',
#  'arreglado',
#  'arreglados',
#  'arreglar',
#  'arreglara',
#  'arreglarlo',
#  'arreglaron',
#  'arregles',
#  'arreglo',
#  'arreglos',
#  'arregló',
#  'arremangó',
#  'arreola',
#  'arrepiente',
#  'arriaban',
#  'arriar',
#  'arriba',
#  'arribita',
#  'arrieros',
#  'arriesgamos',
#  'arriesgando',
#  'arriesgaron',
#  'arriesgáramos',
#  'arrima',
#  'arrimaba',
#  'arrimada',
#  'arrimando',
#  'arrimarse',
#  'arrime',
#  'arrimo',
#  'arrimándose',
#  'arrimármelos',
#  'arrimó',
#  'arrobalo',
#  'arrojaba',
#  'arroyo',
#  'arroz',
#  'arréglense',
#  'arte',
#  'artes',
#  'artesanía',
#  'arto',
#  'artos',
#  'arócutin',
#  'asa',
#  'asadas',
#  'asaditas',
#  'asadito',
#  'asaditos',
#  'asado',
#  'asajo',
#  'asaltan',
#  'asaltar',
#  'asalté',
#  'asamblea',
#  'asan',
#  'asando',
#  'asar',
#  'asarlo',
#  'asarlos',
#  'ascii',
#  'asegurado',
#  'asegurar',
#  'aseguren',
#  'aseguro',
#  'asentamiento',
#  'asentaron',
#  'asi',
#  'asian',
#  'asiente',
#  'asignan',
#  'asina',
#  'asinita',
#  'asistencia',
#  'asistente',
#  'asistía',
#  'asistían',
#  'asoman',
#  'asomó',
#  'aspecto',
#  'asquerosa',
#  'ass',
#  'asunto',
#  'asust',
#  'asusta',
#  'asustaba',
#  'asustadas',
#  'asustado',
#  'asustan',
#  'asustar',
#  'asustarlo',
#  'asusté',
#  'asustó',
#  'asá',
#  'asì',
#  'así',
#  'ata',
#  'ataca',
#  'atacar',
#  'ataque',
#  'ate',
#  'atecua',
#  'atekua',
#  'atención',
#  'atender',
#  'atendiera',
#  'atendió',
#  'atendían',
#  'atenta',
#  'aterrizamos',
#  'ates',
#  'atestigar',
#  'atestiguamos',
#  'atestiguar',
#  'atienden',
#  'atole',
#  'atolito',
#  'atorar',
#  'atracción',
#  'atraer',
#  'atrapado',
#  'atrapen',
#  'atravesaba',
#  'atravesaban',
#  'atravesar',
#  'atravesó',
#  'atraviesa',
#  'atraviese',
#  'atraía',
#  'atrevió',
#  'atrio',
#  'atropellan',
#  ...]

# %%
print(tf_matrix)
# Out:
#   (0, 2660)	10
#   (0, 5595)	1
#   (0, 5558)	2
#   (0, 6859)	2
#   (0, 8996)	2
#   (0, 5931)	1
#   (0, 656)	1
#   (0, 6668)	1
#   (0, 6045)	1
#   (0, 1172)	1
#   (0, 447)	1
#   (0, 3491)	1
#   (0, 3414)	1
#   (0, 5022)	1
#   (0, 641)	1
#   (0, 4160)	1
#   (0, 8985)	3
#   (0, 7943)	8
#   (0, 1193)	4
#   (0, 8738)	1
#   (0, 5683)	3
#   (0, 5718)	2
#   (0, 8008)	1
#   (0, 5500)	1
#   (0, 486)	1
#   :	:
#   (9, 5985)	1
#   (9, 8855)	1
#   (9, 1444)	1
#   (9, 2572)	1
#   (9, 8851)	2
#   (9, 8201)	1
#   (9, 8655)	2
#   (9, 1443)	1
#   (9, 3463)	2
#   (9, 8266)	1
#   (9, 4948)	1
#   (9, 7448)	2
#   (9, 7918)	1
#   (9, 3236)	1
#   (9, 6404)	1
#   (9, 8265)	2
#   (9, 8210)	1
#   (9, 5452)	1
#   (9, 1192)	1
#   (9, 1587)	1
#   (9, 6733)	1
#   (9, 6592)	1
#   (9, 6789)	1
#   (9, 3202)	1
#   (9, 5059)	1

# %%
tf_matrix
# Out:
# <409x9069 sparse matrix of type '<class 'numpy.int64'>'
# 	with 66475 stored elements in Compressed Sparse Row format>

# %%
pd.DataFrame(tf_matrix.toarray())[486]
# Out:
# 0      1
# 1      2
# 2      5
# 3      2
# 4      0
#       ..
# 404    1
# 405    0
# 406    0
# 407    0
# 408    0
# Name: 486, Length: 409, dtype: int64

# %% [markdown]
# http://www.ultravioletanalytics.com/blog/tf-idf-basics-with-pandas-scikit-learn
#
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html
